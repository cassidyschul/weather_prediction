# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()

# %%
#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns = ['EIN', 'NAME'])

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

#  Cutoff value is 156
cutoff_value = 156
application_types_to_replace = application_df['APPLICATION_TYPE'].value_counts()[application_df['APPLICATION_TYPE'].value_counts() <= cutoff_value].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts[classification_counts > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

#  Classification cuttoff value is 1883
classifications_to_replace = classification_counts[classification_counts < 1883].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
categorical_columns = ['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS']
application_df_encoded = pd.get_dummies(application_df, columns=categorical_columns)

# %%
# Split our preprocessed data into our features and target arrays
X = application_df_encoded.drop(columns=['IS_SUCCESSFUL'])
y = application_df_encoded['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5981 (23.36 KB)
# Trainable params: 5981 (23.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

#Create a callback that saves the model's weights every five epochs.
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    # Path to save the model file
    filepath='model_weights_epoch_{epoch:02d}.h5',
    # Save only the model's weights
    save_weights_only=True,
    # Save every 5 epochs
    save_freq=5*len(X_train_scaled)
)

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5687 - accuracy: 0.7242
# Epoch 2/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5557 - accuracy: 0.7259
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5527 - accuracy: 0.7280
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5507 - accuracy: 0.7301
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5499 - accuracy: 0.7308
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7309
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5481 - accuracy: 0.7317
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5471 - accuracy: 0.7322
# Epoch 9/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5466 - accuracy: 0.7317
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7328
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7334
# Epoch 12/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5453 - accuracy: 0.7323
# Epoch 13/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5445 - accuracy: 0.7334
# Epoch 14/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5449 - accuracy: 0.7336
# Epoch 15/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5434 - accuracy: 0.7332
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5439 - accuracy: 0.7348
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7353
# Epoch 18/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5432 - accuracy: 0.7334
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5427 - accuracy: 0.7350
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7348
# Epoch 21/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5424 - accuracy: 0.7359
# Epoch 22/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5425 - accuracy: 0.7364
# Epoch 23/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5418 - accuracy: 0.7348
# Epoch 24/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5415 - accuracy: 0.7362
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5416 - accuracy: 0.7359
# Epoch 26/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5406 - accuracy: 0.7354
# Epoch 27/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5409 - accuracy: 0.7373
# Epoch 28/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5403 - accuracy: 0.7358
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5405 - accuracy: 0.7372
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7367
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7371
# Epoch 32/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5398 - accuracy: 0.7381
# Epoch 33/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5397 - accuracy: 0.7374
# Epoch 34/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5397 - accuracy: 0.7381
# Epoch 35/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5395 - accuracy: 0.7378
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5393 - accuracy: 0.7372
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7372
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7388
# Epoch 39/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5389 - accuracy: 0.7377
# Epoch 40/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5386 - accuracy: 0.7367
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5386 - accuracy: 0.7376
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7379
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5384 - accuracy: 0.7378
# Epoch 44/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5383 - accuracy: 0.7387
# Epoch 45/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5379 - accuracy: 0.7379
# Epoch 46/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5378 - accuracy: 0.7389
# Epoch 47/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5377 - accuracy: 0.7385
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7377
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5376 - accuracy: 0.7385
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7382
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5373 - accuracy: 0.7398
# Epoch 52/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5369 - accuracy: 0.7375
# Epoch 53/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5371 - accuracy: 0.7390
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7385
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7396
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7392
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5369 - accuracy: 0.7394
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7388
# Epoch 59/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5365 - accuracy: 0.7383
# Epoch 60/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5368 - accuracy: 0.7386
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7382
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.7395
# Epoch 63/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5359 - accuracy: 0.7393
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.7388
# Epoch 65/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5353 - accuracy: 0.7397
# Epoch 66/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5357 - accuracy: 0.7393
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7388
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7401
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7401
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7391
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7399
# Epoch 72/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5357 - accuracy: 0.7385
# Epoch 73/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5357 - accuracy: 0.7389
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7401
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7404
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5357 - accuracy: 0.7397
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7393
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7397
# Epoch 79/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5349 - accuracy: 0.7398
# Epoch 80/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5350 - accuracy: 0.7400
# Epoch 81/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5354 - accuracy: 0.7405
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7400
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7403
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7396
# Epoch 85/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5350 - accuracy: 0.7408
# Epoch 86/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5346 - accuracy: 0.7400
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7394
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7400
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5346 - accuracy: 0.7409
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7402
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5348 - accuracy: 0.7406
# Epoch 92/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5345 - accuracy: 0.7401
# Epoch 93/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5348 - accuracy: 0.7400
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7407
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7410
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7408
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5340 - accuracy: 0.7406
# Epoch 98/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5344 - accuracy: 0.7401
# Epoch 99/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5342 - accuracy: 0.7403
# Epoch 100/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5343 - accuracy: 0.7403

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5617 - accuracy: 0.7297 - 628ms/epoch - 2ms/step
# Loss: 0.5617400407791138, Accuracy: 0.72967928647995

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
